# %%
# !pip install pyqrcode
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyqrcode: filename=PyQRCode-1.2.1-py3-none-any.whl size=36223 sha256=b48062e1d2988fc4d39e2c1329c23b6e5c208d233474f4fd2200e87c47e8e82c
#   Stored in directory: /root/.cache/pip/wheels/34/2d/20/082874e49a32cdcc87ebaf99dd0099fb7774ef30f010dfb6f2
# Successfully built pyqrcode
# ...

# %%
import pyqrcode

#Esta es la que convertiremos a QR
url = "www.youtube.com"
qr_code = pyqrcode.create(url)

#Ahora creamos y guardamos el archivo
qr_code.svg("QR_Youtube.svg", scale=8)
